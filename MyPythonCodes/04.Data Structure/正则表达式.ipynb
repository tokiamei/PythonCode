# %%
import re

# %% [markdown]
# # 正则字符串

# %% [markdown]
# ![image.png](attachment:c97e1ad9-d60e-4909-a7ed-063dc7f919ab.png)

# %% [markdown]
# ![image.png](attachment:b8a1e892-0319-4190-9239-def69d45bfe3.png)

# %% [markdown]
# ![image.png](attachment:567532e0-9160-44f7-89f1-428d4e2aa836.png)

# %% [markdown]
# ![image.png](attachment:f2163241-8bdb-416a-a06a-0028cf114fe4.png)

# %% [markdown]
# ## re.search()方法
#     若匹配到，则返回匹配到的第一个匹配结果
#     若未匹配到，则返回None

# %%
string = '2a 3 bc'

re.search(r'\s', string)
# Out:
# <re.Match object; span=(2, 3), match=' '>

# %%
# 'run' or 'ran'
res = re.search(r'r[au]n','dog runs to cat')
print(res)
# Out:
# <re.Match object; span=(4, 7), match='run'>

# %%
# continue 匹配更多种可能
# res = re.search(r'r[A-Z]n','dog rans to cat')
res = re.search(r'r[a-z]n','dog rans to cat')
print(res)
# Out:
# <re.Match object; span=(4, 7), match='ran'>

# %%
res = re.search(r'r[0-9]n','dog rans to cat')
print(res)
# Out:
# None

# %%
res = re.search(r'r[0-9a-z]n','dog rans to cat')
print(res)
# Out:
# <re.Match object; span=(4, 7), match='ran'>

# %%
if None: print(1)

# %% [markdown]
# ## re.findall()
#     在字符串中找到正则表达式所匹配的所有子串，并返回一个列表，如果没有找到匹配的，则返回空列表
