# %%
import pandas as pd

# %%
df = pd.read_excel('江苏省考候选-xqz.xlsx')
# df.head
# df[df['专　业'] == '计算机(软件)类、电子信息类']
# df[df['专　业'].isin(['电子信息类', '计算机类'])]
# df[df['专　业'].str.contains(['电子信息类', '计算机类'])] # error
# df[df['专　业'].str.contains('电子信息类')] 
df[df['专　业'].str.contains('电子信息类|计算机类')]

# %%
sk = pd.read_excel('副本08-淮安市.xls')
# sk.to_string()
pd.set_option('display.max_rows', None)
sk[( sk['专　业'].str.contains('计算机类|电子信息类') ) & ( ~sk['其　它'].str.contains('女性|应届毕业生|视力|中共党员') )]
# sk['专　业']
# Out:
#     隶属  关系  地区  代码   地区  名称  单位代码      单位名称  职位代码                       职位名称  \
# 39       市   80000      淮安市    14      市住建局     1                  信用信息处一级科员
# 70      乡镇   80300   淮安市淮安区   801   山阳街道办事处     1                       一级科员
# 72      乡镇   80300   淮安市淮安区   899      乡镇机关     2                       一级科员
# 96       县   80400   淮安市淮阴区   301      区城管局     1   区城市管理行政执法大队一级行政执法员(参照管理)
# 100     乡镇   80400   淮安市淮阴区   899      乡镇机关     1                       一级科员
# 131      县   81200  淮安市清江浦区    11      区财政局     1                    办公室一级科员
# 138      县   81200  淮安市清江浦区    30    区市场监管局     2                淮中分局一级行政执法员
# 153      县   81300   淮安市洪泽区     5      区科技局     1                    办公室一级科员
# 170      县   81300   淮安市洪泽区    29      区统计局     1                工业能源统计科一级科员
# 230      县   82600      涟水县    31  县退役军人事务局     1                    办公室一级科员
# 235     乡镇   82600      涟水县   801   涟城街道办事处     2                       一级科员
# 238     乡镇   82600      涟水县   899      乡镇机关     1                       一级科员
# 310     乡镇   83000      盱眙县   899      乡镇机关     1                       一级科员
# 337      县   83100      金湖县     3      县工信局     1                产业发展推进科一级科员
# 338      县   83100      金湖县     4    县教育体育局     1                  组织人事科一级科员
# 362      县   83100      金湖县    30    县市场监管局     3  市场监管综合行政执法大队一级行政执法员(参照管理)
# 363      县   83100      金湖县    30    县市场监管局     4  市场监管综合行政执法大队一级行政执法员(参照管理)
# 368     乡镇   83100      金湖县   802   戴楼街道办事处     1                       一级科员
#
#                       职位简介 考试类别  开考比例  招考人数    学　历                    专　业  \
# 39      从事住建系统信息化、信用建设相关工作    A     3     1  本科及以上         计算机(软件)类、电子信息类
# 70              从事经济管理相关工作    C     3     1  本科及以上               经济类、计算机类
# 72              从事工业经济发展工作    C     3     5  本科及以上      电子信息类、机电控制类、机械工程类
# 96                从事城管执法工作    B     3     1  本科及以上             计算机类、建筑工程类
# 100        从事工业经济、园区帮办服务工作    C     3     1  本科及以上            电子信息类、材料工程类
# 131               从事综合管理工作    A     3     1  本科及以上             中文文秘类、计算机类
# 138  从事网络管理、系统维护、特种设备监管等工作    B     3     1  本科及以上             计算机类、机械工程类
# 153               从事科技管理工作    A     3     1  本科及以上              经济类、电子信息类
# 170                 从事统计工作    A     3     1  本科及以上         统计类、财务财会类、计算机类
# 230             从事综合管理服务工作    A     3     1  本科及以上               统计类、计算机类
# 235             从事工业经济发展工作    C     3     3  本科及以上   经济类、计算机类、机电控制类、环境保护类
# 238             从事工业经济发展工作    C     3     4  本科及以上      电子信息类、机械工程类、材料工程类
# 310               从事综合管理工作    C     3     3  本科及以上             中文文秘类、计算机类
# 337           从事产业发展服务相关工作    A     3     1  本科及以上     机电控制类、统计类、计算机类、经济类
# 338           从事教育单位综合管理工作    A     3     1  本科及以上                   计算机类
# 362         从事市场监管综合行政执法工作    B     3     1  本科及以上        电子信息类、化学工程类、药学类
# 363         从事市场监管综合行政执法工作    B     3     1  本科及以上             计算机类、安全生产类
# 368             从事基层日常管理工作    C     3     1  本科及以上  电子信息类、艺术类、机械工程类、公共管理类
#
#                             其　它
# 39                       取得相应学位
# 70                       取得相应学位
# 72                       取得相应学位
# 96   取得相应学位，从事室外一线执法和夜间渣土运输巡查工作
# 100                      取得相应学位
# 131                      取得相应学位
# 138                      取得相应学位
# 153                      取得相应学位
# 170                      取得相应学位
# 230                      取得相应学位
# 235                      取得相应学位
# 238                      取得相应学位
# 310                      取得相应学位
# 337                      取得相应学位
# 338                      取得相应学位
# 362                      取得相应学位
# 363          取得相应学位，从事一线执法，需值夜班
# 368                      取得相应学位
